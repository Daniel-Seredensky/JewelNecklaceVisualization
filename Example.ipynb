# %%
from Map import Map
from JewelList import JewelList

# %%
jList = JewelList(8,"Red","Green","Blue")
print(jList)
# Out:
# Red 1, Red 2, Red 3, Red 4, Red 5, Blue 6, Red 7, Green 8, Blue 9, Green 10,

# %%
map = Map(jList)

# %%
map.collapse()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 map.collapse()
#
# File ~/Desktop/Projects/PythonFolder/JewelNecklaceVisualization/Map.py:160, in Map.collapse(self)
#     156   fig.update_traces(marker=dict(color="maroon",opacity=.75))
#     157   fig.update_scenes(xaxis_title_text='x',
#     158                     yaxis_title_text='y',
#     159                     zaxis_title_text='z')
# --> 160   fig.show()
#     161 if self.canPlot3D:
#     162   x,y,z = self.col_data[:,0],self.col_data[:,1],[0 for x in range(len(self.col_data[:,0]))]
#
# File ~/Desktop/Projects/PythonFolder/JewelNecklaceVisualization/.conda/lib/python3.11/site-packages/plotly/basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
# ...

# %%
map.animateCollapse4D()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 map.animateCollapse4D()
#
# File ~/Desktop/Projects/PythonFolder/JewelNecklaceVisualization/Map.py:207, in Map.animateCollapse4D(self)
#     205 ax.set_ylabel("y")
#     206 ax.set_zlabel("z")
# --> 207 ax.set_xlim(-1, max(3, np.max(mapNonAns[:, 0]) if len(mapNonAns) > 0 else 3))
#     208 ax.set_ylim(-1, max(3, np.max(mapNonAns[:, 1]) if len(mapNonAns) > 0 else 3))
#     209 ax.set_zlim(-1, max(3, np.max(mapNonAns[:, 2]) if len(mapNonAns) > 0 else 3))
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
map.answers
# Out:
# [[-0.5000000000000001, 0.4, 0.049999999999999996, 0.049999999999999996],
#  [0.5000000000000001, -0.4, -0.049999999999999996, -0.049999999999999996],
#  [-0.5000000000000001, 0.049999999999999996, 0.4, 0.049999999999999996],
#  [0.5000000000000001, -0.049999999999999996, -0.4, -0.049999999999999996],
#  [-0.5000000000000001, 0.049999999999999996, 0.049999999999999996, 0.4],
#  [0.5000000000000001, -0.049999999999999996, -0.049999999999999996, -0.4],
#  [0.4, -0.5000000000000001, 0.049999999999999996, 0.049999999999999996],
#  [-0.4, 0.5000000000000001, -0.049999999999999996, -0.049999999999999996],
#  [0.4, 0.049999999999999996, -0.5000000000000001, 0.049999999999999996],
#  [-0.4, -0.049999999999999996, 0.5000000000000001, -0.049999999999999996],
#  [0.4, 0.049999999999999996, 0.049999999999999996, -0.5000000000000001],
#  [-0.4, -0.049999999999999996, -0.049999999999999996, 0.5000000000000001],
#  [0.049999999999999996, 0.4, -0.5000000000000001, 0.049999999999999996],
# ...

# %%
# Out:
# [1, 2, 3]

# %%
# Out:
# 1365

# %%
# Out:
# [np.float64(664.9999999999998), np.float64(2016.0), np.float64(5186.999999999997), np.float64(11647.999999999996), np.float64(23517.000000000004), np.float64(43680.0)]

# %%
# Out:
# [1, 2]
